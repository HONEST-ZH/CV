# %%
from matplotlib import image as mpimg
from matplotlib import pyplot as plt
img1 = mpimg.imread('image/LenaNoise.png')
plt.imshow(img1)

# %%
import cv2
cv2.imshow("CV2show", img1)  # 扩展为 BGR 通道

cv2.waitKey(0)
cv2.destroyAllWindows()  # 释放所有窗口

# %%
#方法1
img2 = cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)
#plt.imshow(img2)
cv2.imshow("CV2show", img2)  # 扩展为 BGR 通道
cv2.waitKey(0)
cv2.destroyAllWindows()  # 释放所有窗口

# %%
# #方法2
# import numpy as np
# ch1, ch2, ch3 = cv2.split(img1)  # 拆分为 RGB独立通道
# imgZeros = np.zeros_like(img1)  # 创建与 img1 相同形状的黑色图像

# SysImg = imgZeros
# SysImg[:,:,2] = ch1  # 在黑色图像模板添加B色分量  

# SysImg = imgZeros
# SysImg[:,:,1] = ch2  # 在黑色图像模板添加G色分量  

# SysImg = imgZeros
# SysImg[:,:,0] = ch3  # 在黑色图像模板添加R色分量  

# cv2.imshow("channe l", SysImg)      
# cv2.waitKey(0)
# cv2.destroyAllWindows()  # 释放所有窗口
